# %%
import cv2
import matplotlib.pyplot as plt

import torch

from ultralytics import solutions
from ultralytics import YOLO
from ultralytics.solutions import AIGym
from ultralytics.utils.plotting import Annotator
import numpy as np

# %%
def track_and_detect(im0, model, CFG):
    """
    입력 이미지에서 객체 추적 및 감지를 수행합니다.
    :param im0: 입력 이미지
    :return: 감지된 객체 및 그 정보를 포함한 트랙
    """
    # im0 = im0.cpu().numpy()
    # print(im0)
    
    tracks = model.track(source=im0, persist=True, classes = CFG["classes"])[0]
    print(tracks.boxes.id.cpu().numpy() if tracks.boxes.id is not None else "No IDs detected")
    return tracks

# %%
def smooth_angles(angle_list, base_window_size=15):
    """
    적응형 이동 평균 필터를 사용하여 노이즈를 완화하되 극값을 유지합니다.

    :param angle_list: 각도 기록 리스트
    :param base_window_size: 기본 윈도우 크기 (기본값 10)
    :return: 부드럽게 처리된 각도 값
    """
    if len(angle_list) < base_window_size:
        return angle_list[-1]

    # 지수적 증가 가중치 적용: 최근 데이터에 훨씬 더 높은 가중치를 부여
    weights = np.exp(np.linspace(0, 1, base_window_size))  # 0에서 2까지 선형 증가 후 이를 지수로 변환하여 가중치 생성
    weights /= np.sum(weights)  # 가중치 합이 1이 되도록 정규화
    smoothed_angle = np.sum(np.array(angle_list[-base_window_size:]) * weights)
    return smoothed_angle

# %%
def calculate_angle(kpts, annotator, angle_history, prev_angle):
    """
    주어진 키포인트를 사용하여 관절 각도를 계산하고 부드럽게 처리합니다.
    :param kpts: 관절 각도를 계산하기 위한 키포인트
    :return: 부드럽게 처리된 관절 각도
    """
    # 키포인트의 수가 충분하지 않은 경우 초기 프레임에서 발생하는 노이즈 방지
    if len(kpts) < 3 or any(kpt is None for kpt in kpts):
        print("Insufficient keypoints detected, skipping angle calculation.")
        return prev_angle  # 이전 각도를 유지하여 노이즈 최소화

    current_angle = annotator.estimate_pose_angle(*kpts)  # 키포인트를 사용하여 각도 추정
    angle_history.append(current_angle)  # 현재 각도를 각도 기록에 추가

    # 충분한 데이터가 쌓이기 전까지는 노이즈 감소를 위해 이전 각도 사용
    if len(angle_history) < 15:
        return prev_angle
    # 만약 충분한 데이터가 있을 경우.
    else :
        return smooth_angles(angle_list = angle_history)

# %%
def process_keypoints(kpts, keypoints):
    """
    사전 정의된 인덱스를 기반으로 특정 신체 부위의 키포인트를 추출합니다.
    :param keypoints: 이미지에서 감지된 키포인트
    :return: 목표 신체 부위의 키포인트 리스트
    """
    kpts = [keypoints[int(kpts[i])].cpu() for i in range(3)]  # 세 개의 관련된 포인트에 대한 키포인트 추출
    return kpts

# %%
def evaluate_range_of_motion(start_idx, end_idx, angle_history, max_threshold, min_threshold):
    """
    주어진 반복 구간에서 각도의 극대값과 극소값을 평가합니다.
    :param start_idx: 반복 구간의 시작 인덱스
    :param end_idx: 반복 구간의 종료 인덱스
    """
    angle_segment = angle_history[start_idx:end_idx]

    # 극대값과 극소값을 찾습니다.
    max_value = max(angle_segment)
    min_value = min(angle_segment)
    
    current_value = angle_segment[-1] # '미는 운동'에 한해서 사용한다. 당기는 운동일 경우 거꾸로.
    if current_value - min_value < 30 : 
        print('너무 조금 들어올렸거나, 올바르지 못한 탐지입니다.')
        return False

    # 최대값 및 최소값 평가
    if max_value < max_threshold:
        print(f"주의: 최대 가동 범위가 충분하지 않습니다. 최대 각도: {max_value:.2f}° (임계값: {max_threshold}°)")
        return False
    else : 
        print(f"올바른 최대 가동 범위입니다. 최대 각도: {max_value:.2f}°")

    if min_value > min_threshold:
        print(f"주의: 최소 가동 범위가 충분하지 않습니다. 최소 각도: {min_value:.2f}° (임계값: {min_threshold}°)")
        return False
    else : 
        print(f"올바른 최소 가동 범위입니다. 최소 각도: {min_value:.2f}°")
    
    if max_value >= max_threshold and min_value <= min_threshold :
        print("올바른 가동범위를 수행했습니다.")
        return True

# %%
def calculate_repetition_speed(current_frame, previous_frame):
    """
    수축과 이완을 통해 한 번의 반복이 완료되었을 때 운동 속도를 계산합니다.
    
    :param previous_time: 이전 반복의 타임스탬프
    :param speed_data: 시간 차이를 저장하는 리스트
    :return: 업데이트된 이전 타임스탬프
    """
    frame_diff = current_frame - previous_frame
    time_diff = frame_diff / 30 # 30FPS이므로 30으로 나눈다. 

    print(f"이번 반복의 속도: {time_diff:.2f}초")
    return time_diff

# %%
def get_video_index_by_threshold(threshold):
    if threshold < 10:
        return 0
    elif threshold < 20:
        return 1
    elif threshold < 30:
        return 2
    else:
        return 3

# %%
 #? press 류 운동에 맞게 설계되었다. 
 #? relax / contract / 
class CustomAIGym(AIGym):
    def __init__(self, tracking_id=1, max_angle = 140, min_angle = 80, workout_type = "press", **kwargs):
        super().__init__(**kwargs)  # AIGym 클래스 상속
        
        self.tracking_id = tracking_id  # 추적 대상 객체 ID
        
        self.count = [0]  # 반복 횟수 초기화
        self.stage = [None]  # 운동 상태 초기화 (예: 수축 또는 이완)
        self.prev_angle = (max_angle + min_angle)/2
        
        self.angle_history = []  # 관절 각도 변화를 저장할 리스트 - 노이즈는 제거되지 않음
        self.angle_hist_plot = [] # 관절 각도 변화를 저장할 리스트 - 노이즈는 제거됨, 플롯용
        
        self.count_history = []  # 반복 횟수 변화 기록 리스트
        
        self.speed_data = []  # 각 운동 반복의 속도(시간 차이)를 저장할 리스트
        self.angle_change_hist = [] # 각도의 변화량을 기록할 리스트
        ## TODO
        
        self.current_idx = 0
        self.time_diff = [0]
        
        self.max_angle = max_angle
        self.min_angle = min_angle
        self.workout_type = workout_type #? 이제는 필요없다. 
        
        self.threshold = 1
        self.goal = 5
        # 가동범위가 너무 적은 경우
        # 일정 시간 이상 낮은 속도를 돌파하지 못할 경우
        # 추가...?
        # 만약 threshold가 5이상일 경우 실패.
        # 만약 목표한 개수만큼 채웠다면 성공, last 틀기.
        
    def detect_slow_movement(self, window_size=20, mindiff=1.0):
        """
        최근 window_size 프레임 동안의 평균 각도 변화량을 검사하여,
        운동 속도가 매우 느린 상태(거의 정지 상태)에 있는지 감지하는 메서드.
        
        :param window_size: 검사할 프레임 수
        :param threshold: 평균 각도 변화량 임계값
        """
        if len(self.angle_change_hist) >= window_size:
            recent_changes = self.angle_change_hist[-window_size:]
            avg_change = sum(abs(c) for c in recent_changes) / window_size
            if avg_change < mindiff:
                # 임계값 이하로 각도 변화량이 작으면 운동 속도가 매우 느린 상태로 간주
                #! 실패한 곳
                self.threshold += 1
                print(f"주의: 최근 {window_size} 프레임 동안 각도 변화량이 평균 {avg_change:.2f}° 이하입니다. 운동 속도가 매우 느립니다.")


    def update_stage(self, current_angle):
        """
        관절 각도 변화에 따라 운동의 현재 상태를 업데이트합니다.
        :param current_angle: 현재 관절 각도
        :return: 운동의 업데이트된 상태 (예: 수축 또는 이완)
        """
        if self.prev_angle is not None : 
            angle_diff = current_angle - self.prev_angle  # 현재 각도와 이전 각도의 차이 계산
        else :
            angle_diff = 0
        
        self.angle_change_hist.append(angle_diff) # 각도 변화량 기록하기. 
        
        self.detect_slow_movement(window_size=30, mindiff=1.0)
    
        # 운동 종류에 따른 변수 설정.
        if self.workout_type == "press" :
            up = "contraction"
            down = "relaxation"
            self.kpts = [6, 8, 10]
        elif self.workout_type == "pull" :
            up = "relaxation"
            down = "contraction"
            self.kpts = [6, 8, 10]
        elif self.workout_type == "legs" :
            up = "contraction"
            down = "relaxation"
            self.kpts = [12, 14, 16]            

        # 각도 변화에 따라 현재 상태 결정
        if angle_diff < -3:  # 각도가 충분히 감소한 경우 이완 단계로 설정
            current_stage = down
        elif angle_diff > 3:  # 각도가 충분히 증가한 경우 수축 단계으로 설정
            current_stage = up
        else:  # 변화가 미미한 경우 현재 상태 유지
            current_stage = "-"

        # 수축에서 이완으로 전환될 때 반복 횟수 증가
        if self.stage[0] == up and current_stage == "-" :
            # 일단 인덱스 기록. 수축/이완이 바뀔 때마다 일단 기록한다.
            # 시작 인덱스는 이전 극값의 프레임
            start_idx = self.current_idx
            # 끝 인덱스는 현재 극값의 프레임.
            end_idx = len(self.angle_history)
            # 가동 범위 평가: 이전 반복 구간의 시작 인덱스부터 현재까지
            print("index is : ",start_idx, end_idx)
            is_full = evaluate_range_of_motion(start_idx, end_idx, angle_history=self.angle_history, max_threshold=self.max_angle, min_threshold=self.min_angle)
            # 올바른 최대 가동범위일 경우
            if is_full == True : 
                self.count[0] += 1  # 반복 횟수 증가
                # 반복 횟수 증가 시 속도 계산하고, 속도 기록 리스트에 추가.
                self.time_diff[0] = calculate_repetition_speed(current_frame=end_idx, previous_frame=start_idx)  # 반복 횟수 증가 시 운동 속도 계산
                print(f"Repetition Count Incremented: {self.count[0]}")
                # 그리고 현재 인덱스를 업데이트해준다...
                self.current_idx = end_idx
            else : 
                print("Not counted.")
                # self.threshold += 1
                # 다른 여러 문제로 인해 못하겠다..
                
        # 현재 상태와 이전 각도 업데이트
        self.stage[0] = current_stage
        self.prev_angle = current_angle
        
        # 해당 프레임 시점에 반복 횟수를 리스트로 추가. 
        # 잘 된다는 사실 확인. 
        self.count_history.append(self.count[0])  # 반복 횟수 기록 추가
        self.speed_data.append(round(self.time_diff[0], 3))
        return current_stage

    def annotate_image(self, im0, keypoints, current_angle, current_stage):
        """
        이미지에 키포인트, 현재 각도, 반복 횟수 및 운동 상태를 주석으로 표시합니다.
        :param im0: 주석을 추가할 입력 이미지
        :param keypoints: 이미지에서 감지된 키포인트
        :param current_angle: 현재 관절 각도
        :param current_stage: 운동의 현재 상태
        :return: 주석이 추가된 이미지
        """
        # 이미지에 특정 키포인트 그리기
        im0 = self.annotator.draw_specific_points(keypoints, self.kpts, radius=self.line_width)
        # 이미지에 각도, 반복 횟수 및 운동 상태 정보 표시
        self.annotator.plot_angle_and_count_and_stage(
            angle_text=current_angle,
            count_text=self.count[0],
            stage_text=f"{current_stage}, {self.angle_change_hist[-1]:.2f}",
            center_kpt=keypoints[1],  # 팔꿈치 키포인트를 중심으로 텍스트 표시
        )
        return im0

    def monitor(self, im0):
        """
        추적 대상 감지, 키포인트 처리 및 이미지 주석을 수행하는 메인 모니터링 함수입니다.
        :param im0: 입력 이미지
        :return: 주석이 추가된 이미지
        """
        
        tracks = track_and_detect(im0=im0, model = self.model, CFG=self.CFG)  # 이미지에서 객체 추적 및 감지 수행
        self.annotator = Annotator(im0, line_width=self.line_width)  # Annotator 인스턴스 생성

        current_angle = None  # 현재 각도를 초기화

        if tracks.boxes.id is not None:
            # 감지된 객체와 그 키포인트들을 반복 처리
            for obj_id, keypoints in zip(tracks.boxes.id.cpu().numpy(), tracks.keypoints.data):
                if obj_id == self.tracking_id:  # 지정된 ID를 가진 추적 대상만 처리
                    print(f"Processing target ID: {self.tracking_id}")
                    kpts = process_keypoints(kpts = self.kpts, keypoints = keypoints)  # 대상 객체의 키포인트 추출
                    current_angle = calculate_angle(kpts=kpts, prev_angle = self.prev_angle, angle_history = self.angle_history, annotator=self.annotator)  # 현재 관절 각도 계산
                    self.angle_hist_plot.append(current_angle)
                    current_stage = self.update_stage(current_angle)  # 운동 상태 업데이트
                    im0 = self.annotate_image(im0, kpts, current_angle, current_stage)  # 이미지에 주석 추가

        self.display_output(im0)  # 주석이 추가된 이미지 출력
        
        video_index = get_video_index_by_threshold(self.threshold)
        
        #영상 재생이 아닐 경우 - video_index에 해당하는 영상 재생. 
        
        if self.count[0] >= self.goal :
            video_index = 4
        
        return im0, video_index

    def plot_training_data(self):
        """
        관절 각도 변화, 반복 횟수, 운동 속도 데이터를 통합적으로 시각화합니다.
        """
        fig, axs = plt.subplots(4, 1, figsize=(10, 15))

        # Plot angle history
        axs[0].plot(self.angle_hist_plot, label='Angle History', color='b')
        axs[0].set_xlabel('Time Steps')
        axs[0].set_ylabel('Joint Angle (degrees)')
        axs[0].set_title('Joint Angle History Over Time')
        axs[0].legend()
        axs[0].grid(True)

        # Plot count history
        axs[1].plot(self.count_history, label='Repetition Count', color='g', marker='o')
        axs[1].set_xlabel('Repetitions')
        axs[1].set_ylabel('Count')
        axs[1].set_title('Repetition Count Over Time')
        axs[1].legend()
        axs[1].grid(True)

        # Plot speed data
        axs[2].plot(self.speed_data, label='Repetition Speed', color='r', marker='o')
        axs[2].set_xlabel('Repetitions')
        axs[2].set_ylabel('Speed (seconds)')
        axs[2].set_title('Repetition Speed Over Time')
        axs[2].legend()
        axs[2].grid(True)
        
        axs[3].plot(self.angle_change_hist, label='Angle diff', color='b', marker='o')
        axs[3].set_xlabel('Repetitions')
        axs[3].set_ylabel('Aangle diff')
        axs[3].set_title('Angle Diff Over Time')
        axs[3].legend()
        axs[3].grid(True)

        plt.tight_layout()
        plt.show()

# %%
video_paths = [
    "video/1.mp4",
    "video/2.mp4",
    "video/3.mp4",
    "video/4.mp4",
    "video/5.mp4"
]

# %%
input_video = "incline bench press/DB_press_1.mp4"

# %%
output_path = input_video + "annotated.mp4"

# %%
gym = CustomAIGym(
    line_width=2,
    show=True,
    model="yolo11m-pose.pt",
    tracking_id=1,
    max_angle=120,
    min_angle=90,
    workout_type = "press",
)
# Out:
# Ultralytics Solutions:  {'region': None, 'show_in': True, 'show_out': True, 'colormap': None, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'json_file': None, 'line_width': 2, 'show': True, 'model': 'yolo11m-pose.pt'}

# %%
# 웹캠 설정
webcam_index = 0
cap = cv2.VideoCapture(webcam_index)
assert cap.isOpened(), "웹캠을 열 수 없습니다."

# 출력 파일 경로
output_path = "output_video.mp4"

# 웹캠 영상 속성 가져오기
w, h = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
original_fps = cap.get(cv2.CAP_PROP_FPS)
if original_fps == 0 or original_fps is None:
    original_fps = 15.0  # FPS 정보를 제대로 얻지 못하면 임의로 15FPS 사용

fps = 15  # 원하는 FPS로 처리 가능

# 비디오 작성기 설정 (분석 결과를 저장)
video_writer = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*"mp4v"), fps, (w // 2, h // 2))

# 초기 video_index 설정
current_video_index = get_video_index_by_threshold(gym.threshold)
cap2 = cv2.VideoCapture(video_paths[current_video_index])
if not cap2.isOpened():
    print(f"Error opening secondary video: {video_paths[current_video_index]}")
    
# cv2.namedWindow("Feedback Video", cv2.WINDOW_NORMAL)  # 윈도우 크기 변경 가능
# cv2.setWindowProperty("Feedback Video", cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

n_tries = 0
while True:
    # 웹캠에서 프레임 읽기
    success, im0 = cap.read()
    if not success:
        print("웹캠 프레임을 읽을 수 없습니다. 종료합니다.")
        break

    # 프레임 크기 조정 (분석 용도)
    im0 = cv2.resize(im0, (w, h))

    # 운동 분석 (monitor 함수 호출)
    im0, new_video_index = gym.monitor(im0)

    # video_index가 바뀌었는지 확인하여 피드백 영상 전환
    if new_video_index != current_video_index:
        # 이전 피드백 영상 캡쳐 객체 해제
        if cap2.isOpened():
            cap2.release()
        current_video_index = new_video_index
        new_video_path = video_paths[current_video_index]
        cap2 = cv2.VideoCapture(new_video_path)
        if not cap2.isOpened():
            print(f"Error: Could not open {new_video_path}")
        else:
            print(f"Switched to video: {new_video_path}")

    # 현재 video_index에 해당하는 피드백 영상에서 프레임 읽기
    ret2, frame2 = cap2.read()
    if not ret2:
        # 피드백 영상이 끝났다면 다시 처음부터 재생
        cap2.set(cv2.CAP_PROP_POS_FRAMES, 0)
        ret2, frame2 = cap2.read()
        if not ret2:
            print("피드백 영상 재생 불가.")
            break

    # 피드백 영상 표시
    cv2.imshow("Feedback Video", frame2)

    # 분석 결과 영상(운동 분석 영상) 저장
    video_writer.write(im0)
    # cv2.imshow("Exercise Analysis", im0)

    n_tries += 1

    # 'q' 키를 누르면 종료
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cap2.release()
video_writer.release()
cv2.destroyAllWindows()

print("비디오 저장이 완료되었습니다.")
# Out:
# 0: 480x640 1 person, 39.4ms
# Speed: 1.0ms preprocess, 39.4ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 39.9ms
# Speed: 1.0ms preprocess, 39.9ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 40.0ms
# Speed: 2.0ms preprocess, 40.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 36.5ms
# Speed: 2.0ms preprocess, 36.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 36.5ms
# Speed: 2.0ms preprocess, 36.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 37.0ms
# Speed: 2.0ms preprocess, 37.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.0ms
# Speed: 1.0ms preprocess, 34.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.0ms
# Speed: 2.0ms preprocess, 34.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.3ms
# Speed: 1.0ms preprocess, 33.3ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.4ms
# Speed: 2.0ms preprocess, 33.4ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.2ms
# Speed: 2.0ms preprocess, 33.2ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.8ms
# Speed: 2.0ms preprocess, 33.8ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.5ms
# Speed: 2.0ms preprocess, 33.5ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.5ms
# Speed: 3.0ms preprocess, 33.5ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.0ms
# Speed: 2.0ms preprocess, 34.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.9ms
# Speed: 1.1ms preprocess, 34.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.1ms
# Speed: 4.0ms preprocess, 34.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 36.0ms
# Speed: 3.0ms preprocess, 36.0ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.2ms
# Speed: 3.0ms preprocess, 34.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 36.5ms
# Speed: 1.0ms preprocess, 36.5ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 39.3ms
# Speed: 2.0ms preprocess, 39.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 37.0ms
# Speed: 2.0ms preprocess, 37.0ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 41.0ms
# Speed: 3.0ms preprocess, 41.0ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 44.0ms
# Speed: 2.0ms preprocess, 44.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 42.6ms
# Speed: 2.0ms preprocess, 42.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 41.6ms
# Speed: 3.0ms preprocess, 41.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.0ms
# Speed: 2.0ms preprocess, 34.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 36.0ms
# Speed: 4.0ms preprocess, 36.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 37.6ms
# Speed: 3.0ms preprocess, 37.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 32.5ms
# Speed: 4.0ms preprocess, 32.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.0ms
# Speed: 5.0ms preprocess, 34.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.0ms
# Speed: 3.0ms preprocess, 34.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 32.9ms
# Speed: 2.0ms preprocess, 32.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 35.0ms
# Speed: 2.0ms preprocess, 35.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 37.3ms
# Speed: 4.0ms preprocess, 37.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.0ms
# Speed: 1.5ms preprocess, 34.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# index is :  0 39
# 올바른 최대 가동 범위입니다. 최대 각도: 166.30°
# 올바른 최소 가동 범위입니다. 최소 각도: 41.83°
# 올바른 가동범위를 수행했습니다.
# 이번 반복의 속도: 1.30초
# Repetition Count Incremented: 1
#
# 0: 480x640 1 person, 32.5ms
# Speed: 2.0ms preprocess, 32.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 35.1ms
# Speed: 3.0ms preprocess, 35.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 39.0ms
# Speed: 2.9ms preprocess, 39.0ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.3ms
# Speed: 2.0ms preprocess, 34.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 35.1ms
# Speed: 2.0ms preprocess, 35.1ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 38.0ms
# Speed: 3.0ms preprocess, 38.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.1ms
# Speed: 2.0ms preprocess, 33.1ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 36.7ms
# Speed: 2.0ms preprocess, 36.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.0ms
# Speed: 3.0ms preprocess, 34.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 35.1ms
# Speed: 1.0ms preprocess, 35.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.1ms
# Speed: 2.0ms preprocess, 33.1ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 42.0ms
# Speed: 4.3ms preprocess, 42.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 37.5ms
# Speed: 5.0ms preprocess, 37.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 54.0ms
# Speed: 4.5ms preprocess, 54.0ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 39.6ms
# Speed: 6.0ms preprocess, 39.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.0ms
# Speed: 2.0ms preprocess, 33.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.1ms
# Speed: 2.0ms preprocess, 33.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.0ms
# Speed: 3.0ms preprocess, 34.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 36.0ms
# Speed: 2.0ms preprocess, 36.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.1ms
# Speed: 2.0ms preprocess, 33.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 35.0ms
# Speed: 1.9ms preprocess, 35.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.6ms
# Speed: 3.0ms preprocess, 34.6ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.6ms
# Speed: 3.0ms preprocess, 34.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.6ms
# Speed: 3.0ms preprocess, 33.6ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 35.7ms
# Speed: 3.0ms preprocess, 35.7ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 32.0ms
# Speed: 3.1ms preprocess, 32.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.6ms
# Speed: 3.0ms preprocess, 34.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.1ms
# Speed: 2.9ms preprocess, 34.1ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 32.6ms
# Speed: 2.1ms preprocess, 32.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 36.5ms
# Speed: 3.0ms preprocess, 36.5ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 37.9ms
# Speed: 4.0ms preprocess, 37.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 42.1ms
# Speed: 6.0ms preprocess, 42.1ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 32.8ms
# Speed: 3.0ms preprocess, 32.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 32.4ms
# Speed: 2.1ms preprocess, 32.4ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.5ms
# Speed: 3.0ms preprocess, 33.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 36.4ms
# Speed: 2.0ms preprocess, 36.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# index is :  39 75
# 올바른 최대 가동 범위입니다. 최대 각도: 161.28°
# 올바른 최소 가동 범위입니다. 최소 각도: 33.56°
# 올바른 가동범위를 수행했습니다.
# 이번 반복의 속도: 1.20초
# Repetition Count Incremented: 2
#
# 0: 480x640 1 person, 34.9ms
# Speed: 2.2ms preprocess, 34.9ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.3ms
# Speed: 1.0ms preprocess, 33.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.6ms
# Speed: 2.0ms preprocess, 33.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.0ms
# Speed: 1.0ms preprocess, 34.0ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 40.0ms
# Speed: 4.0ms preprocess, 40.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 56.2ms
# Speed: 4.0ms preprocess, 56.2ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 42.0ms
# Speed: 3.0ms preprocess, 42.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 35.9ms
# Speed: 2.1ms preprocess, 35.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 39.0ms
# Speed: 4.5ms preprocess, 39.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.5ms
# Speed: 2.0ms preprocess, 33.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 36.0ms
# Speed: 3.0ms preprocess, 36.0ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.5ms
# Speed: 2.8ms preprocess, 34.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.3ms
# Speed: 3.0ms preprocess, 34.3ms inference, 9.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.4ms
# Speed: 2.0ms preprocess, 33.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 36.0ms
# Speed: 4.0ms preprocess, 36.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 44.1ms
# Speed: 3.1ms preprocess, 44.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.0ms
# Speed: 3.5ms preprocess, 33.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.4ms
# Speed: 4.8ms preprocess, 33.4ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 58.6ms
# Speed: 4.9ms preprocess, 58.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.3ms
# Speed: 3.0ms preprocess, 33.3ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 45.0ms
# Speed: 3.0ms preprocess, 45.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 42.8ms
# Speed: 3.0ms preprocess, 42.8ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 47.4ms
# Speed: 3.1ms preprocess, 47.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 49.4ms
# Speed: 2.0ms preprocess, 49.4ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 37.0ms
# Speed: 5.0ms preprocess, 37.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 45.9ms
# Speed: 6.0ms preprocess, 45.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 49.1ms
# Speed: 2.0ms preprocess, 49.1ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 40.2ms
# Speed: 4.3ms preprocess, 40.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.6ms
# Speed: 2.0ms preprocess, 33.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 38.3ms
# Speed: 2.5ms preprocess, 38.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 47.0ms
# Speed: 4.8ms preprocess, 47.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# index is :  75 107
# 올바른 최대 가동 범위입니다. 최대 각도: 154.93°
# 올바른 최소 가동 범위입니다. 최소 각도: 32.79°
# 올바른 가동범위를 수행했습니다.
# 이번 반복의 속도: 1.07초
# Repetition Count Incremented: 3
#
# 0: 480x640 1 person, 32.5ms
# Speed: 2.0ms preprocess, 32.5ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 32.8ms
# Speed: 2.0ms preprocess, 32.8ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 45.5ms
# Speed: 4.0ms preprocess, 45.5ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.2ms
# Speed: 2.2ms preprocess, 33.2ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 35.0ms
# Speed: 2.0ms preprocess, 35.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.5ms
# Speed: 2.0ms preprocess, 33.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.6ms
# Speed: 3.0ms preprocess, 33.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.0ms
# Speed: 2.0ms preprocess, 33.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.0ms
# Speed: 2.0ms preprocess, 33.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.0ms
# Speed: 3.0ms preprocess, 34.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.6ms
# Speed: 2.0ms preprocess, 33.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.0ms
# Speed: 2.0ms preprocess, 33.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.0ms
# Speed: 2.0ms preprocess, 33.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.1ms
# Speed: 3.0ms preprocess, 33.1ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 32.5ms
# Speed: 2.0ms preprocess, 32.5ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 32.8ms
# Speed: 2.0ms preprocess, 32.8ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.6ms
# Speed: 2.4ms preprocess, 33.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.0ms
# Speed: 2.1ms preprocess, 33.0ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.0ms
# Speed: 1.5ms preprocess, 33.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.1ms
# Speed: 2.6ms preprocess, 33.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 35.4ms
# Speed: 2.0ms preprocess, 35.4ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 51.9ms
# Speed: 2.1ms preprocess, 51.9ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 61.3ms
# Speed: 2.0ms preprocess, 61.3ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.0ms
# Speed: 2.7ms preprocess, 33.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 45.0ms
# Speed: 3.0ms preprocess, 45.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 42.0ms
# Speed: 4.0ms preprocess, 42.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.1ms
# Speed: 1.5ms preprocess, 33.1ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 45.1ms
# Speed: 7.3ms preprocess, 45.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# index is :  107 135
# 올바른 최대 가동 범위입니다. 최대 각도: 156.23°
# 올바른 최소 가동 범위입니다. 최소 각도: 27.02°
# 올바른 가동범위를 수행했습니다.
# 이번 반복의 속도: 0.93초
# Repetition Count Incremented: 4
#
# 0: 480x640 1 person, 38.7ms
# Speed: 4.2ms preprocess, 38.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 42.0ms
# Speed: 3.1ms preprocess, 42.0ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 43.1ms
# Speed: 4.0ms preprocess, 43.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 46.1ms
# Speed: 3.0ms preprocess, 46.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 50.9ms
# Speed: 3.5ms preprocess, 50.9ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.1ms
# Speed: 2.0ms preprocess, 34.1ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 32.1ms
# Speed: 3.0ms preprocess, 32.1ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.0ms
# Speed: 2.1ms preprocess, 33.0ms inference, 6.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 42.1ms
# Speed: 2.0ms preprocess, 42.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 32.0ms
# Speed: 3.0ms preprocess, 32.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.0ms
# Speed: 4.0ms preprocess, 33.0ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 49.2ms
# Speed: 3.0ms preprocess, 49.2ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.3ms
# Speed: 2.0ms preprocess, 33.3ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 45.0ms
# Speed: 3.0ms preprocess, 45.0ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 63.9ms
# Speed: 4.0ms preprocess, 63.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.1ms
# Speed: 3.0ms preprocess, 34.1ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 41.5ms
# Speed: 4.0ms preprocess, 41.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.0ms
# Speed: 3.9ms preprocess, 33.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 32.0ms
# Speed: 3.0ms preprocess, 32.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.2ms
# Speed: 2.0ms preprocess, 34.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 40.8ms
# Speed: 3.1ms preprocess, 40.8ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.0ms
# Speed: 5.0ms preprocess, 33.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.1ms
# Speed: 5.0ms preprocess, 34.1ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.3ms
# Speed: 5.1ms preprocess, 34.3ms inference, 6.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.0ms
# Speed: 2.0ms preprocess, 33.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.5ms
# Speed: 3.0ms preprocess, 34.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 32.7ms
# Speed: 2.0ms preprocess, 32.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.1ms
# Speed: 2.0ms preprocess, 33.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# index is :  135 163
# 올바른 최대 가동 범위입니다. 최대 각도: 156.70°
# 올바른 최소 가동 범위입니다. 최소 각도: 27.52°
# 올바른 가동범위를 수행했습니다.
# 이번 반복의 속도: 0.93초
# Repetition Count Incremented: 5
# Switched to video: video/5.mp4
#
# 0: 480x640 1 person, 34.9ms
# Speed: 2.0ms preprocess, 34.9ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 45.0ms
# Speed: 4.0ms preprocess, 45.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 37.4ms
# Speed: 1.0ms preprocess, 37.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.5ms
# Speed: 4.0ms preprocess, 33.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 35.4ms
# Speed: 2.0ms preprocess, 35.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 37.9ms
# Speed: 2.1ms preprocess, 37.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.2ms
# Speed: 2.0ms preprocess, 33.2ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 36.9ms
# Speed: 3.0ms preprocess, 36.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.9ms
# Speed: 2.1ms preprocess, 33.9ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 52.1ms
# Speed: 3.9ms preprocess, 52.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 35.0ms
# Speed: 2.0ms preprocess, 35.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.6ms
# Speed: 3.3ms preprocess, 33.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 32.6ms
# Speed: 1.1ms preprocess, 32.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 37.4ms
# Speed: 2.4ms preprocess, 37.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.0ms
# Speed: 2.0ms preprocess, 33.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.0ms
# Speed: 3.0ms preprocess, 34.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.6ms
# Speed: 1.9ms preprocess, 33.6ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 32.8ms
# Speed: 3.1ms preprocess, 32.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.8ms
# Speed: 1.0ms preprocess, 33.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.0ms
# Speed: 2.0ms preprocess, 34.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.2ms
# Speed: 2.0ms preprocess, 33.2ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.1ms
# Speed: 3.0ms preprocess, 33.1ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 32.0ms
# Speed: 2.0ms preprocess, 32.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.7ms
# Speed: 1.9ms preprocess, 33.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.0ms
# Speed: 1.1ms preprocess, 33.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.1ms
# Speed: 2.0ms preprocess, 33.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# index is :  163 190
# 올바른 최대 가동 범위입니다. 최대 각도: 159.66°
# 올바른 최소 가동 범위입니다. 최소 각도: 30.99°
# 올바른 가동범위를 수행했습니다.
# 이번 반복의 속도: 0.90초
# Repetition Count Incremented: 6
#
# 0: 480x640 1 person, 34.1ms
# Speed: 2.0ms preprocess, 34.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.6ms
# Speed: 2.0ms preprocess, 33.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 32.0ms
# Speed: 4.0ms preprocess, 32.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.4ms
# Speed: 2.0ms preprocess, 34.4ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.2ms
# Speed: 2.0ms preprocess, 33.2ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.4ms
# Speed: 3.0ms preprocess, 33.4ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 32.9ms
# Speed: 2.1ms preprocess, 32.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 36.5ms
# Speed: 2.0ms preprocess, 36.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.1ms
# Speed: 2.0ms preprocess, 34.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.5ms
# Speed: 5.0ms preprocess, 34.5ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 32.6ms
# Speed: 2.0ms preprocess, 32.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.0ms
# Speed: 4.0ms preprocess, 33.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 55.0ms
# Speed: 4.4ms preprocess, 55.0ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 45.0ms
# Speed: 3.9ms preprocess, 45.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 52.0ms
# Speed: 3.0ms preprocess, 52.0ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 40.1ms
# Speed: 3.9ms preprocess, 40.1ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 44.0ms
# Speed: 1.9ms preprocess, 44.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.1ms
# Speed: 5.5ms preprocess, 33.1ms inference, 5.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.8ms
# Speed: 3.0ms preprocess, 33.8ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.9ms
# Speed: 2.1ms preprocess, 33.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 35.0ms
# Speed: 3.0ms preprocess, 35.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.1ms
# Speed: 3.0ms preprocess, 33.1ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.5ms
# Speed: 3.1ms preprocess, 33.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.3ms
# Speed: 2.0ms preprocess, 33.3ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.5ms
# Speed: 2.0ms preprocess, 33.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.1ms
# Speed: 3.0ms preprocess, 34.1ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.6ms
# Speed: 2.0ms preprocess, 33.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.2ms
# Speed: 2.0ms preprocess, 33.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 32.3ms
# Speed: 2.1ms preprocess, 32.3ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.9ms
# Speed: 2.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.1ms
# Speed: 2.0ms preprocess, 33.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 35.9ms
# Speed: 2.0ms preprocess, 35.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# index is :  190 223
# 올바른 최대 가동 범위입니다. 최대 각도: 158.10°
# 올바른 최소 가동 범위입니다. 최소 각도: 34.82°
# 올바른 가동범위를 수행했습니다.
# 이번 반복의 속도: 1.10초
# Repetition Count Incremented: 7
#
# 0: 480x640 1 person, 34.1ms
# Speed: 1.5ms preprocess, 34.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.6ms
# Speed: 2.0ms preprocess, 33.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.0ms
# Speed: 2.0ms preprocess, 33.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.3ms
# Speed: 3.2ms preprocess, 33.3ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 39.2ms
# Speed: 3.5ms preprocess, 39.2ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 48.6ms
# Speed: 4.0ms preprocess, 48.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 36.6ms
# Speed: 2.0ms preprocess, 36.6ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.6ms
# Speed: 3.0ms preprocess, 34.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.8ms
# Speed: 3.0ms preprocess, 33.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 45.0ms
# Speed: 2.0ms preprocess, 45.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.0ms
# Speed: 2.0ms preprocess, 34.0ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 39.5ms
# Speed: 3.0ms preprocess, 39.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.0ms
# Speed: 4.0ms preprocess, 34.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 47.3ms
# Speed: 5.0ms preprocess, 47.3ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 55.2ms
# Speed: 2.1ms preprocess, 55.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 54.6ms
# Speed: 3.0ms preprocess, 54.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 42.0ms
# Speed: 2.0ms preprocess, 42.0ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.1ms
# Speed: 3.0ms preprocess, 33.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 47.1ms
# Speed: 3.0ms preprocess, 47.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.1ms
# Speed: 2.9ms preprocess, 34.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 50.4ms
# Speed: 3.0ms preprocess, 50.4ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 55.1ms
# Speed: 3.0ms preprocess, 55.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 37.6ms
# Speed: 3.0ms preprocess, 37.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 62.7ms
# Speed: 4.0ms preprocess, 62.7ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 40.0ms
# Speed: 3.0ms preprocess, 40.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 32.9ms
# Speed: 6.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 32.6ms
# Speed: 3.0ms preprocess, 32.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.6ms
# Speed: 2.0ms preprocess, 33.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 37.1ms
# Speed: 4.0ms preprocess, 37.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 36.0ms
# Speed: 3.0ms preprocess, 36.0ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# index is :  223 256
# 올바른 최대 가동 범위입니다. 최대 각도: 152.01°
# 올바른 최소 가동 범위입니다. 최소 각도: 29.49°
# 올바른 가동범위를 수행했습니다.
# 이번 반복의 속도: 1.10초
# Repetition Count Incremented: 8
#
# 0: 480x640 1 person, 36.7ms
# Speed: 2.0ms preprocess, 36.7ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.7ms
# Speed: 2.0ms preprocess, 33.7ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 37.0ms
# Speed: 2.0ms preprocess, 37.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 58.7ms
# Speed: 5.0ms preprocess, 58.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 43.1ms
# Speed: 4.0ms preprocess, 43.1ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 40.2ms
# Speed: 2.0ms preprocess, 40.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.0ms
# Speed: 4.0ms preprocess, 34.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 53.4ms
# Speed: 4.0ms preprocess, 53.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.1ms
# Speed: 2.5ms preprocess, 33.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 58.4ms
# Speed: 3.1ms preprocess, 58.4ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 41.6ms
# Speed: 1.9ms preprocess, 41.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 51.5ms
# Speed: 4.0ms preprocess, 51.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 38.1ms
# Speed: 2.0ms preprocess, 38.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 45.0ms
# Speed: 4.3ms preprocess, 45.0ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.7ms
# Speed: 4.0ms preprocess, 34.7ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 55.7ms
# Speed: 3.0ms preprocess, 55.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 52.2ms
# Speed: 3.5ms preprocess, 52.2ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 50.0ms
# Speed: 3.9ms preprocess, 50.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 47.1ms
# Speed: 3.0ms preprocess, 47.1ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 33.0ms
# Speed: 4.0ms preprocess, 33.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 32.4ms
# Speed: 3.5ms preprocess, 32.4ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 36.4ms
# Speed: 3.0ms preprocess, 36.4ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 41.6ms
# Speed: 4.0ms preprocess, 41.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# index is :  256 280
# 올바른 최대 가동 범위입니다. 최대 각도: 153.98°
# 올바른 최소 가동 범위입니다. 최소 각도: 26.42°
# 올바른 가동범위를 수행했습니다.
# 이번 반복의 속도: 0.80초
# Repetition Count Incremented: 9
#
# 0: 480x640 1 person, 39.5ms
# Speed: 2.2ms preprocess, 39.5ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 42.0ms
# Speed: 4.0ms preprocess, 42.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 39.9ms
# Speed: 3.0ms preprocess, 39.9ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 34.9ms
# Speed: 2.1ms preprocess, 34.9ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
#
# 0: 480x640 1 person, 43.6ms
# ...
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.11° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 33.5ms
# Speed: 2.0ms preprocess, 33.5ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.11° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 33.6ms
# Speed: 2.0ms preprocess, 33.6ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.12° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 32.9ms
# Speed: 2.1ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.14° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.15° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 34.0ms
# Speed: 2.0ms preprocess, 34.0ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.16° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 32.6ms
# Speed: 2.0ms preprocess, 32.6ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.18° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 32.7ms
# Speed: 2.0ms preprocess, 32.7ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.18° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 2 persons, 32.9ms
# Speed: 2.0ms preprocess, 32.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1           7]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.18° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 2 persons, 32.9ms
# Speed: 2.1ms preprocess, 32.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1           7]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.19° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 2 persons, 32.9ms
# Speed: 1.7ms preprocess, 32.9ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1           7]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.19° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 2 persons, 37.8ms
# Speed: 1.1ms preprocess, 37.8ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
# [          1           7]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.19° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 2 persons, 38.6ms
# Speed: 1.1ms preprocess, 38.6ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1           7]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.19° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 2 persons, 33.6ms
# Speed: 3.0ms preprocess, 33.6ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1           7]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.19° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 2 persons, 34.1ms
# Speed: 3.0ms preprocess, 34.1ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1           7]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.19° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 2 persons, 34.0ms
# Speed: 2.0ms preprocess, 34.0ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1           7]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.18° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 2 persons, 40.0ms
# Speed: 2.9ms preprocess, 40.0ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1           7]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.18° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 2 persons, 33.0ms
# Speed: 2.9ms preprocess, 33.0ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1           7]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.18° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 2 persons, 33.0ms
# Speed: 2.0ms preprocess, 33.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1           7]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.18° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 2 persons, 34.0ms
# Speed: 2.6ms preprocess, 34.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1           7]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.18° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 2 persons, 32.5ms
# Speed: 1.1ms preprocess, 32.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1           7]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.18° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 2 persons, 33.0ms
# Speed: 2.0ms preprocess, 33.0ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1           7]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.18° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 33.1ms
# Speed: 2.0ms preprocess, 33.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.18° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 32.5ms
# Speed: 2.0ms preprocess, 32.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.19° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 33.5ms
# Speed: 2.0ms preprocess, 33.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.19° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 33.9ms
# Speed: 2.1ms preprocess, 33.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.20° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 33.0ms
# Speed: 2.0ms preprocess, 33.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.20° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 35.2ms
# Speed: 2.0ms preprocess, 35.2ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.20° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 33.6ms
# Speed: 2.1ms preprocess, 33.6ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.19° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 33.2ms
# Speed: 2.0ms preprocess, 33.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.20° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 32.4ms
# Speed: 2.0ms preprocess, 32.4ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.20° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 34.0ms
# Speed: 3.0ms preprocess, 34.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.20° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 33.9ms
# Speed: 2.0ms preprocess, 33.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.20° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 34.8ms
# Speed: 3.0ms preprocess, 34.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.19° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 48.0ms
# Speed: 3.0ms preprocess, 48.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.18° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 40.5ms
# Speed: 3.0ms preprocess, 40.5ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.17° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 37.1ms
# Speed: 3.0ms preprocess, 37.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.16° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 37.0ms
# Speed: 3.0ms preprocess, 37.0ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.15° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 39.0ms
# Speed: 4.0ms preprocess, 39.0ms inference, 11.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.14° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 35.0ms
# Speed: 2.0ms preprocess, 35.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.13° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 34.9ms
# Speed: 2.1ms preprocess, 34.9ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.13° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 36.0ms
# Speed: 3.0ms preprocess, 36.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.12° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 34.0ms
# Speed: 2.0ms preprocess, 34.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.12° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 39.0ms
# Speed: 2.0ms preprocess, 39.0ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.13° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 47.0ms
# Speed: 2.7ms preprocess, 47.0ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.13° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 34.0ms
# Speed: 2.0ms preprocess, 34.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.13° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 33.6ms
# Speed: 1.9ms preprocess, 33.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.14° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 33.1ms
# Speed: 2.0ms preprocess, 33.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.14° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 33.0ms
# Speed: 2.0ms preprocess, 33.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.14° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 34.1ms
# Speed: 2.0ms preprocess, 34.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.14° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 33.0ms
# Speed: 1.6ms preprocess, 33.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.14° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 32.6ms
# Speed: 2.9ms preprocess, 32.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.14° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 36.0ms
# Speed: 2.0ms preprocess, 36.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.14° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 39.0ms
# Speed: 3.0ms preprocess, 39.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.14° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 34.5ms
# Speed: 2.1ms preprocess, 34.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.13° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 38.6ms
# Speed: 2.9ms preprocess, 38.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.13° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 41.5ms
# Speed: 3.0ms preprocess, 41.5ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.12° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 57.6ms
# Speed: 3.0ms preprocess, 57.6ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.12° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 39.9ms
# Speed: 2.1ms preprocess, 39.9ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.11° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 48.9ms
# Speed: 2.7ms preprocess, 48.9ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.10° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 44.9ms
# Speed: 3.1ms preprocess, 44.9ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.10° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 51.1ms
# Speed: 2.9ms preprocess, 51.1ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.09° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 39.0ms
# Speed: 3.1ms preprocess, 39.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.09° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 49.0ms
# Speed: 3.0ms preprocess, 49.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.08° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 39.0ms
# Speed: 2.5ms preprocess, 39.0ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.07° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 32.8ms
# Speed: 3.0ms preprocess, 32.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.07° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 32.0ms
# Speed: 3.0ms preprocess, 32.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.07° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 32.9ms
# Speed: 2.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.07° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 38.0ms
# Speed: 2.0ms preprocess, 38.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.07° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 33.2ms
# Speed: 2.0ms preprocess, 33.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.07° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 32.5ms
# Speed: 2.1ms preprocess, 32.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.07° 이하입니다. 운동 속도가 매우 느립니다.
#
# 0: 480x640 1 person, 33.0ms
# Speed: 2.0ms preprocess, 33.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [          1]
# Processing target ID: 1
# 주의: 최근 30 프레임 동안 각도 변화량이 평균 0.07° 이하입니다. 운동 속도가 매우 느립니다.
# 비디오 저장이 완료되었습니다.

# %%
gym.plot_training_data()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 gym.plot_training_data()
#
# NameError: name 'gym' is not defined
